# %%
import os
import pandas as pd
from spectral.io import envi
from spectral.io.envi import read_envi_header
from glob import glob

os.chdir('/store/carroll/sbgplants/')

# %%
out_folder = 'data/out_csv'

table = 'spatial_ref_sys'

# %%
# prepare & populate out table

out_table = pd.DataFrame(index=[0])

out_table['srid'] = 32613
out_table['auth_name'] = 'EPSG'
out_table['auth_srid'] = 32613
out_table['srtext'] = 'PROJCS["WGS 84 / UTM zone 13N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-105],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32613"]]'
out_table['proj4text'] = '+proj=utm +zone=13 +datum=WGS84 +units=m +no_defs'

out_table
# Out:
#     srid auth_name auth_srid  \
# 0  32613      EPSG     32613
#
#                                               srtext  \
# 0  PROJCS["WGS 84 / UTM zone 13N",GEOGCS["WGS 84"...
#
#                                            proj4text
# 0  +proj=utm +zone=13 +datum=WGS84 +units=m +no_defs

# %%
# check data types
out_table.dtypes
# Out:
# srid          int64
# auth_name    object
# auth_srid    object
# srtext       object
# proj4text    object
# dtype: object

# %%
# export table
fp_out = os.path.join(out_folder, f'{table}.csv')
out_table.to_csv(fp_out, index=False)
